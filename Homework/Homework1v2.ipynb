# %% [markdown]
# <b><font size=20, color='#A020F0'>Homework 1</font></b>

# %% [markdown]
# #### In this homework you'll further practice basic python and you'll also get a chance to build your own python environment.
#
# <b><font color='red'>Due Date: 16 September 2026</font></b><br>(by the beginning of class)
#
# <b>How you will turn in this assignment</b><br> When you are ready to turn in your homework, do the following:
# 1. Execute all cells in your notebook so that the results are visible. It is ok if you have code that you practiced with, but <b><u>make sure your final answers to each question are clearly marked so that your TA and I know what to grade</u></b>. (See example setup in Question 1 below). You can also collapse the code and outputs that you _don't_ want us to grade; options to collapse and expand code are in the `View` menu in the upper left
# 2. Open a terminal and navigate to your local `aos573_completed_assignments` repository and make a new directory called `completed_HW1`
# 3. Move your completed jupyter notebook, your external `.py` script and screenshot (Q1.3), and your `.yml` python environment file (Q2.1) into this directory (when you do this git will effectively assume you deleted the files from the current directory, so you need to add and commit those changes as well)
# 4. `add` and `commit` the `completed_HW1` directory and its contents to your local `aos573_completed_assignments` repository
# 5. Finally, `push` your changes to your remote `aos573_completed_assignments` repository: `git push finished_work main` (you'll need to enter your username and personal access token)
#
# <b>Documenting use of AI</b><br>
# <font color='red'><b>If you use AI on a problem, you must document that use<b></font> by doing the following in a notebook cell immediately below where your solution is:
#
# 1. Explain briefly, in your own words, how and why you needed to use AI on the problem.
# 2. Include a screenshot of the prompt AND the output from whatever AI tool you used. Be sure to add and commit any screenshots when you turn in your homework, otherwise we won't be able to see them in the notebook. Basic markdown for including an image in a notebook looks like this:<br> ```![title of the image](picture.png)```

# %% [markdown]
# ---

# %% [markdown]
# ## Part 1: Basic Python

# %% [markdown]
# ### Q1.1 Write a for loop that takes two _lists_ of numbers and multiplies them
# You can make whatever lists of numbers you want. The lists should both be 1D and the multiplication should be elementwise.

# %% [markdown]
# #### A1.1 You can put your answer below a heading like this if you want

# %% [markdown]
# ### Q1.2 Conditional statements
# Say I have the following list of numbers and animals: `1,2,3,'dog','cat',7,11,'bird'`<br>
# I want to write some code that does the following:
# 1. Checks if the number or animal I provide is in the list or not (and tells me so by printing a statement telling me that)
# 2. If the animal or number I provide IS in the list I want the code to tell me whether it's a number or an animal

# %% [markdown]
# ### Q1.3 Create a script
# Create a python script that runs the code your wrote in Q1.2 so you that can run it on the command line with `python my_script.py` (you can name your .py file whatever you want). <b>Make sure the script works by testing it on the command line, <u>and include a screenshot of your script test in a markdown cell below.</u></b> You just need to be able to run the script and have it produce some output (I don't care what the script looks like or how you do it). The script doesn't need to take command line inputs, but if you want to try that, feel free. <b><font color='red'> Don't forget to include your .py script AND your screenshot when turning in your notebook!

# %% [markdown]
# ### Q1.4 Writing your own function
# Given the following information about some random people I made up, write a function that compares the age of any two of them and returns the person that is older. Your function should have two inputs (for the names of the two people you want to compare), and it should output the name of the person that is oldest. Be sure to include comments in your code that describe what your function does and how to use it. <b>Show that your function works by testing it in a new cell below where you write your code in this notebook.</b>
#
# People info:
#
# $\begin{array}{|c|c|}
#  \hline
#  Name & Age \\
#  \hline
#  Larry & 97 \\
#  Barry & 16 \\
#  Gary & 34 \\
#  Jerry & 55 \\
#  \hline
# \end{array}$

# %% [markdown]
# ### Q1.5 Missing values, nan, and zip

# %% [markdown]
# #### Q1.5.1 Using nan and checking whether something is finite
# In our line of work we often have missing values in our data, which can be represented as a particular number (like -99 for example), or nan (not a number). Given the list of numbers below, write some code that does the following:
# 1. Replaces all values of -99 with nan (hint: you'll need to import a package to use nan)
# 2. Makes a new list with only the finite (non-nan) values in it
#
# $a=[1,2,3,4,-99,6,7,-99,9,-99]$

# %% [markdown]
# #### Q1.5.2 Turn the result of 1.5.1 into a function
# Make a function that takes as input an arbitrary list of numbers with missing values and returns a list without those missing values. Design your function so it has a `missing_value` argument, with a default of -99. Test your function with the default missing value by using the original list in 1.5.1. Then test it with the following list, where -999 is the missing value:
#
# $b=[10,20,30,-999,80,-999,-999,-999,90,10]$

# %% [markdown]
# #### Q1.5.3
# Take your lists a and b from 1.5.1 and 1.5.2 (the ones that have replaced the missing values by nans) and construct a loop that returns _only_ the pairs of values (as tuples) from a and b in which _neither_ a _nor_ b is nan.
#
# ><b><font color='green'>Hint:</font></b> [python documentation on zip](https://docs.python.org/3/library/functions.html#zip)

# %% [markdown]
# ### Q1.6 Dictionaries
# #### Q1.6.1
# Given the following table of information for the five people listed below, make a dictionary that associates the correct age, height, and favorite color with each person.
#
# $\begin{array}{|c|c|c|c|}
#  \hline
#  \text{Name} & \text{Age (years)} & \text{Height (inches)} & \text{Favorite Color} \\
#  \hline
#  Jane & 34 & 62 & \text{Red} \\
#  Susanna & 50 & 68 & \text{Green} \\
#  Mark & 82 & 66 & \text{Blue} \\
#  Alice & 21 & 64 & \text{Black} \\
#  Travis & 43 & 74 & \text{Pink} \\
#  Stacy & 65 & 70 & \text{Blue} \\
#  \hline
# \end{array}$

# %% [markdown]
# #### Q1.6.2
# Using the dictionary you created, write some code that 1) computes the age difference between each _unique_ pair of people in the list, and 2) compares the favorite color of each person in a pair and determines if the two colors are the same or different.
#
# <b>Your code must</b>
# 1) Automate this process (i.e., don't type out a set of print statements for each pair just because you can get the solution by looking at the table and figuring out the results yourself)
# 2) Provide all age differences as positive numbers
# 3) Contain only one print statement providing all the requested information for each pair (e.g., the output of your print statement should say something like "Person1 is xx years older/younger than Person2 and Person1 and Person2 do/do not have the same favorite color")

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2: Python environments

# %% [markdown]
# ### 2.1 Create and export a python environment
# 1. Make a new environment in a `.yml` file with the following channels and dependencies (make sure you name your environment!):
# - <b>channels</b>:
#      - conda-forge
# - <b>dependencies</b>:
#      - python (version 3.12)
#      - xarray
#      - matplotlib
#      - numpy (at _least_ version 1.19)
# 2. Create the environment using one of the options discussed in class, activate it, and export it to a new `.yml` file. <b>Use the `--from-history` flag when you export</b>. Make sure your new `.yml` file has a different name from the one you created in Step 1, otherwise you'll overwrite your original file. <b><font color='red'>This exported environment is what you will turn in for this problem!</b></font> (You'll need to add and commit it to your comleted assignments repository)
