# %% [markdown]
# <b><font size=20, color='#A020F0'>Homework 5</font></b>

# %% [markdown]
# #### In this homework you'll further explore seaborn
#
# <b><font color='red'>Due Date: 19 November 2025</font></b><br>(by the beginning of class)
#
# <b>How you will turn in this assignment</b><br> When you are ready to turn in your homework, do the following steps:
# 1. Execute all cells in your notebook so that the results are visible, and save one more time. It is ok if you have code that you practiced with, but <b><u>make sure your final answers to each question are clearly marked so that your TA and I know what to grade</u></b>. (You can also collapse the code and outputs that you _don't_ want us to grade; options to collapse and expand code are in the 'View' menu in the upper left)
# 2. Open a terminal and navigate to your local `aos573_completed_assignments` repository and make a new directory called `completed_HW5`
# 3. Move your completed jupyter notebook (<u>and _only_ your notebook</u>) into this directory
# 4. `add` and `commit` the `completed_HW5` directory and its contents to your local `aos573_completed_assignments` repository
# 5. `push` your changes to your remote `aos573_completed_assignments` repository: `git push finished_work main` (you'll need to enter your username and personal access token)
# 6. <b><font color='red'>REMINDER: DO NOT TRACK OR PUSH THE DATA USED IN THE NOTEBOOK</font></b>

# %% [markdown]
# ---

# %% [markdown]
# ## Part 1: Getting the data

# %% [markdown]
# ### Q1.1 Earthquake data
# For this homework you'll be using data from the [USGS Earthquake Catalog](https://www.usgs.gov/programs/earthquake-hazards/earthquakes) to explore all of the magnitude 5.5+ earthquakes that have happened across the planet over the last 25 years. To do that, you'll need to acquire the data yourself by going to the [catalog search page](https://earthquake.usgs.gov/earthquakes/search/) and providing the following parameters:
#
# 1. Set the **Magnitude** and **Date & Time** options to 'custom' and make sure **Geographic Region** is set to 'world'
# 2. Set the magnitude minium to be 5.5
# 3. Set the date range to be January 1, 2000 to the end of December 31, 2024
# 4. Expand the **Advanced Options** menu and under **Event Type** check the **Earthquakes** box
# 5. Expand the **Output Options** menu and under **Format** choose 'CSV'

# %% [markdown]
# ### Q1.2 Reading in and familiarizing yourself with the data
# Read in your data. Once you have done so, answer the following questions (you can do these with code or write your answers in markdown depending on which makes sense):
#
# 1. Is your data long-form or wide-form?
# 2. How many columns are in your dataset?
# 3. What does each column represent?
#     ><b><font color='red'>Note: </font></b>I do not want detailed explanations for your answers to 3). You should summarize what each column represents in a sentence or less (so just a few words) and include units when appropriate. DO NOT just print out a list of the column names though.

# %% [markdown]
# ---

# %% [markdown]
# ## Part 2: Data exploration with seaborn
# For all of the problems in this section, you are welcome to use a mix of seaborn and matplotlib to make your plots look however you want as long as the specific plotting calls using the earthquake data itself are done in seaborn. <b>Although I have provided specific information about what default parameters you are _required_ to change in your plot, all of the final plots you make in this section must be of high quality, and changes to the defaults need to go beyond what I have asked.</b> If aspects of your plots are not legible, or color combinations make things difficult to see or interpret, etc., <font color='red'>*you will lose points*</font>.
#
# If you're worried about what level I expect here, a good rule of thumb is to ask yourself "would I be caught dead letting this plot see the light of day in a department seminar, a conference, or the like?"

# %% [markdown]
# ### Q2.1 Global map of earthquakes
# #### 2.1.1 Plotting
# Set up a global map of the Earth centered on the Pacific Ocean using a Mollweide projection. Add the following to your plot:
# 1. Coastlines
# 2. A background that shows Earth's topography/bathymetry
# 3. A point at the location of every earthquake in your earthquake dataset from 2015 onward. Make sure each dot's size AND color represent the magnitude of the earthquake.

# %% [markdown]
# #### 2.1.2 Plot interpretation
# List 2-3 general regions that seem to have a lot of earthquakes

# %% [markdown]
# ### Q2.2 Earthquake Counts

# %% [markdown]
# #### Q2.2.1 Plotting
# Make a 2x2 set of histograms showing the number of earthquakes as a function of the following:
# 1. Magnitude (use a bin spacing of 0.25)
# 2. Depth (use a bin spacing of 50 km)
# 3. Latitude (use a bin spacing of 10$\degree$)
# 4. Longitude (use a bin spacing of 20$\degree$ AND make sure your bins go from 0-360, not -180 to 180)
#
# For all plots, change the default colors for the histogram bins and bin edges, and add labels, units (where appropriate), and titles to your plots.

# %% [markdown]
# #### Q2.2.2 Plot interpretation
# Use the plots you made in Q2.2.1 to answer the following questions:
#
# 1. At what magnitude range and what depth range are there the most earthquakes? The fewest? Are these two variables (magnitude and depth) normally distributed?
# 2. Based on your latitude histogram, do you think there could be an underlying relationship between latitude and the number of earthquakes or is it more likely to be a coincidence that they are somewhat normally distributed around the Equator? Briefly justify your answer. It's ok if you know _nothing_ about the physics of earthquakes--instead look at your map from Q2.1 to help you.

# %% [markdown]
# ### Q2.3 Earthquake depth vs. magnitude
#
# #### 2.3.1 Plotting
# Make a scatterplot of earthquake magnitude (y-axis) vs. earthquake depth (x-axis).
# As usual, change the default parameters for the plot in such a way that 1) it looks nice, and 2) you can clearly interpret such a large amount of data.

# %% [markdown]
# #### 2.3.2 Plot interpretation
# Are there any patterns that you notice in the plot?

# %% [markdown]
# ### Q2.4 Temporal variation

# %% [markdown]
# #### Q2.4.1 Plotting
# Make a 1x2 set of boxplots showing 1) the spread of earthquake magnitudes for each year of the dataset and 2) the spread of earthquake magnitudes for each month. Set the whiskers for each box to represent the 1st and 99th percentiles. Change the default plotting output of the boxes (colors, box widths, etc), and add labels and a title to your plots.

# %% [markdown]
# #### 2.4.2 Plot interpretation
# Do your earthquake magnitude distributions seem to vary much from year-to-year or month-to-month?

# %% [markdown]
# #### Q2.4.3 Plotting
# Make a single plot showing earthquake counts vs. year for the following magnitude ranges:
# 1. <6.0
# 2. [6.0-7.0)
# 3. [7.0-8.0)
# 4. [8.0-9.0)
# 5. \>9.0
#
# That means that for each year, you should have 5 categories for magnitude, each distinguished by a separate color.

# %% [markdown]
# #### Q2.4.4 Plot interpretation
# Are there any magnitude ranges for which earthquake counts seem to vary strongly from year-to-year?

# %% [markdown]
# ### Q2.5 A version of the ridge plot
# Starting with the code from [this ridgeplot example](https://seaborn.pydata.org/examples/kde_ridgeplot.html) in the seaborn gallery, make me a similar plot but showing earthquake magnitude for the following depth ranges:
#
# 1. 0-100 km
# 2. 100-200 km
# 3. 200-300 km
# 4. 300-400 km
# 5. 400-500 km
# 6. 500-600 km
# 7. 600-700 km
#
# Instead of a showing the filled kdeplot for each depth range, I want you to show an unfilled version overlaid on the underlying histogram for each. Your final plot should look something like this (but your colors, etc should be different from what is in the example):
#
# <img src='Images/ridgeplot_fun.png'></img>
